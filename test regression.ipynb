# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('annual_temp.csv')
dataset
# Out:
#       Source  Year    Mean
# 0       GCAG  2015  0.8990
# 1    GISTEMP  2015  0.8700
# 2       GCAG  2014  0.7402
# 3    GISTEMP  2014  0.7500
# 4       GCAG  2013  0.6687
# ..       ...   ...     ...
# 267  GISTEMP  1882 -0.1000
# 268     GCAG  1881 -0.0707
# 269  GISTEMP  1881 -0.1200
# 270     GCAG  1880 -0.1247
# 271  GISTEMP  1880 -0.2000
#
# [272 rows x 3 columns]

# %%
new=dataset[dataset.Source != 'GISTEMP']
new
# Out:
#     Source  Year    Mean
# 4     GCAG  2013  0.6687
# 6     GCAG  2012  0.6219
# 8     GCAG  2011  0.5759
# 10    GCAG  2010  0.7008
# 12    GCAG  2009  0.6354
# ..     ...   ...     ...
# 262   GCAG  1884 -0.2099
# 264   GCAG  1883 -0.1481
# 266   GCAG  1882 -0.0710
# 268   GCAG  1881 -0.0707
# 270   GCAG  1880 -0.1247
#
# [134 rows x 3 columns]

# %%
X = new.iloc[:, 1:2].values
y = new.iloc[:, 2:3].values

# %%
X
# Out:
# array([[2013],
#        [2012],
#        [2011],
#        [2010],
#        [2009],
#        [2008],
#        [2007],
#        [2006],
#        [2005],
#        [2004],
#        [2003],
#        [2002],
#        [2001],
#        [2000],
#        [1999],
#        [1998],
#        [1997],
#        [1996],
#        [1995],
#        [1994],
#        [1993],
#        [1992],
#        [1991],
#        [1990],
#        [1989],
#        [1988],
#        [1987],
#        [1986],
#        [1985],
#        [1984],
#        [1983],
#        [1982],
#        [1981],
#        [1980],
#        [1979],
#        [1978],
#        [1977],
#        [1976],
#        [1975],
#        [1974],
#        [1973],
#        [1972],
#        [1971],
#        [1970],
#        [1969],
#        [1968],
#        [1967],
#        [1966],
#        [1965],
#        [1964],
#        [1963],
#        [1962],
#        [1961],
#        [1960],
#        [1959],
#        [1958],
#        [1957],
#        [1956],
# ...

# %%
y
# Out:
# array([[ 0.6687],
#        [ 0.6219],
#        [ 0.5759],
#        [ 0.7008],
#        [ 0.6354],
#        [ 0.5415],
#        [ 0.6113],
#        [ 0.6139],
#        [ 0.6583],
#        [ 0.5806],
#        [ 0.6145],
#        [ 0.6018],
#        [ 0.5455],
#        [ 0.4255],
#        [ 0.4427],
#        [ 0.6335],
#        [ 0.5185],
#        [ 0.3225],
#        [ 0.4593],
#        [ 0.342 ],
#        [ 0.2857],
#        [ 0.2583],
#        [ 0.4079],
#        [ 0.435 ],
#        [ 0.2982],
#        [ 0.377 ],
#        [ 0.371 ],
#        [ 0.2308],
#        [ 0.1357],
#        [ 0.151 ],
#        [ 0.3429],
#        [ 0.1836],
#        [ 0.3024],
#        [ 0.2651],
#        [ 0.2288],
#        [ 0.1139],
#        [ 0.1996],
#        [-0.0769],
#        [ 0.006 ],
#        [-0.0698],
#        [ 0.1654],
#        [ 0.028 ],
#        [-0.0775],
#        [ 0.0383],
#        [ 0.0937],
#        [-0.0282],
#        [-0.0112],
#        [-0.0204],
#        [-0.0752],
#        [-0.1461],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train
# Out:
# array([[1954],
#        [1940],
#        [1980],
#        [1983],
#        [1907],
#        [1908],
#        [1882],
#        [1930],
#        [1885],
#        [2000],
#        [1947],
#        [1928],
#        [1951],
#        [1962],
#        [1998],
#        [1957],
#        [1973],
#        [1903],
#        [1959],
#        [2010],
#        [1915],
#        [2007],
#        [1904],
#        [1952],
#        [1906],
#        [1942],
#        [1892],
#        [1937],
#        [1895],
#        [1919],
#        [1935],
#        [1986],
#        [1995],
#        [1898],
#        [2002],
#        [1912],
#        [1927],
#        [1929],
#        [1924],
#        [1972],
#        [1922],
#        [2012],
#        [1897],
#        [1893],
#        [1971],
#        [2009],
#        [1996],
#        [1975],
#        [2008],
#        [1960],
#        [1887],
#        [1909],
#        [2013],
#        [1979],
#        [1985],
#        [1958],
#        [1938],
#        [1978],
# ...

# %%
y_train
# Out:
# array([[-0.1118],
#        [ 0.0927],
#        [ 0.2651],
#        [ 0.3429],
#        [-0.3767],
#        [-0.4441],
#        [-0.071 ],
#        [-0.1016],
#        [-0.222 ],
#        [ 0.4255],
#        [-0.0455],
#        [-0.1749],
#        [-0.0095],
#        [ 0.0924],
#        [ 0.6335],
#        [ 0.0538],
#        [ 0.1654],
#        [-0.3442],
#        [ 0.064 ],
#        [ 0.7008],
#        [-0.0747],
#        [ 0.6113],
#        [-0.424 ],
#        [ 0.0288],
#        [-0.2208],
#        [ 0.1549],
#        [-0.3079],
#        [-0.0204],
#        [-0.2279],
#        [-0.2082],
#        [-0.1445],
#        [ 0.2308],
#        [ 0.4593],
#        [-0.2578],
#        [ 0.6018],
#        [-0.3318],
#        [-0.1506],
#        [-0.2982],
#        [-0.251 ],
#        [ 0.028 ],
#        [-0.2318],
#        [ 0.6219],
#        [-0.1232],
#        [-0.3221],
#        [-0.0775],
#        [ 0.6354],
#        [ 0.3225],
#        [ 0.006 ],
#        [ 0.5415],
#        [ 0.0252],
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, regressor.predict(X_test), color = 'blue')
plt.title('YEAR vs TEMPERATURE (Test set)')
plt.xlabel('YEAR')
plt.ylabel('TEMPERATURE')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regGc = PolynomialFeatures(degree = 3)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'green')
plt.title('YEAR vs TEMPERATURE graph2')
plt.xlabel('YEAR')
plt.ylabel('TEMPERATURE')
plt.show()

# %%
y_pred = regressor.predict([[2016]])
print("temperature in 2016:")
print(y_pred)
# Out:
# temperature in 2016:
# [[0.46889408]]

# %%
y_pred = regressor.predict([[2017]])
print("temperature in 2017:")
print(y_pred)
# Out:
# temperature in 2017:
# [[0.47530235]]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('YEAR vs TEMPERATURE graph03')
plt.xlabel('YEAR')
plt.ylabel('TEMPERATURE')
plt.show()

# %%
#graph01 is plot by using linear regression ...we can see that the line of regression doest not meet max points
#so we move to polynomial graph..(i have tried on degree 3 and 4 both) we dont get approriate results
#so next we move to random forest ...(i got errors on it)
#then we plot decision tree..here we can see that all the points are joined by a line(not a straight line)
